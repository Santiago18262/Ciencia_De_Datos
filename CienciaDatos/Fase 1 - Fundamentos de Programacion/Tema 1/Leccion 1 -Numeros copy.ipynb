# %% [markdown]
# <h2>Números<h2>

# %%
# Multiplicación de números
6 * 3
# Out:
# 18

# %%
# División de números 
10 / 2
# Out:
# 5.0

# %%
# Modulo a residuo 
16 % 5
# Out:
# 1

# %%
# Potencia
2 ** 3
# Out:
# 8

# %%
# Interpreta las operaciones por orden de precedencia
3-2+4*10
# Out:
# 41

# %%
# Asignacion de un valor a una variable
n = 3
m = 12
resp = n + m
resp
# Out:
# 15

# %%
m + 3
# Out:
# 15

# %%
z = n *2 
n * n
z
# Out:
# 6

# %%
# Repetimos la variable n
n = 5
n * m
# Out:
# 60

# %%
n = m +10

# %%
n
# Out:
# 22
