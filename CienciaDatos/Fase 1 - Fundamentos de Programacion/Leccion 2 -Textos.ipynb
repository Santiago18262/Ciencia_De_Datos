# %% [markdown]
# # **Practica 2 del curso de Programación en Python**

# %%
'Hola'
"Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
'Este texto incluye unas " " comillas dobles'
# Out:
# 'Este texto incluye unas " " comillas dobles'

# %%
"Esta 'palabra' se encuentra entre comillas simples"
# Out:
# "Esta 'palabra' se encuentra entre comillas simples"

# %%
"Una cadena"
'Otra cadena'
# Out:
# 'Otra cadena'

# %%
print('Una cadena')
print("Otra cadena mas")
print('Otra cadena')
# Out:
# Una cadena
# Otra cadena mas
# Otra cadena

# %%
print("Un texto\tEsto es un tab")
# Out:
# Un texto	Esto es un tab

# %%
# La \n sirve para hacer un salto de linea
print("Un texto \n una nueva linea \n otro salto")
# Out:
# Un texto
#  una nueva linea
#  otro salto

# %%
print("C:\nombre\directorio")
# Out:
# C:
# ombre\directorio
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\santi\AppData\Local\Temp\ipykernel_16236\1403242980.py:1: SyntaxWarning: invalid escape sequence '\d'
#   print("C:\nombre\directorio")

# %%
# r permite mostrar datos en crudo..
# es decir la diagonal inversa tal como es
print(r"C:\nombre\directorio")
# Out:
# C:\nombre\directorio

# %%
print("""Una           linea
    otra linea               
    otra mas               """)
# Out:
# Una           linea
#     otra linea
#     otra mas

# %%
c = "Esto es una cadena \ncon dos lineas \n"

# %%
print(c)
# Out:
# Esto es una cadena
# con dos lineas

# %%
c + c
# Out:
# 'Esto es una cadena \ncon dos lineas \nEsto es una cadena \ncon dos lineas \n'

# %%
print(c+c)
# Out:
# Esto es una cadena
# con dos lineas
# Esto es una cadena
# con dos lineas

# %%
s = "Una cadena"  "Compuesta de 2 cadenas"
print (s)
# Out:
# Una cadenaCompuesta de 2 cadenas

# %%
c1 = "Una cadena"
c2 = "Otra cadena"
c3 = c1 + c2
print(c3)
# Out:
# Una cadenaOtra cadena

# %%
palabra = "Python"

# %%
palabra[0]  # Caracter en la posicion 0
# Out:
# 'P'

# %%
palabra[3]
# Out:
# 'h'

# %%
palabra[-1] # Ultimo caracter
# Out:
# 'n'

# %%
palabra[0:2] # Sirve para substraer una cadena
# Out:
# 'Py'

# %%
palabra[0:] # Si no pones el final, toma toda la subcadena
# Out:
# 'Python'

# %%
palabra[:] # Si no indicamos los rangos, nos muestra todo
# Out:
# 'Python'

# %%
palabra[99] # Indice fuera de rango marca un error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 palabra[99] # Indice fuera de rango marca un error
#
# IndexError: string index out of range

# %%
palabra[:99] # No marca error, toma hasta el final
# Out:
# 'Python'
