# %% [markdown]
# ## Listas ##

# %%
lista = [1, 2, 3, 4, 5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista.append(6)
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista.clear()
lista
# Out:
# []

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l1.extend(l2)

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1.count(2)
# Out:
# 1

# %%
"Hola mundo hola Mundo hoka".count('mundo')
# Out:
# 1

# %%
l = [1,2,3]
l.insert(0,0) # Insertamos un 0 en la posicion 0
l.insert(5,6)
l
# Out:
# [0, 1, 2, 3, 6]

# %%
l
# Out:
# [0, 1, 2, 3, 6]

# %%
l = [5,10,15,25]
l.insert(-1,6)

# %%
l
# Out:
# [5, 10, 15, 6, 25]

# %%
l
l.insert(-3,10)

# %%
l
# Out:
# [5, 10, 10, 15, 6, 25]

# %%
l.pop()
# Out:
# 25

# %%
l
# Out:
# [5, 10, 10, 15, 6]
