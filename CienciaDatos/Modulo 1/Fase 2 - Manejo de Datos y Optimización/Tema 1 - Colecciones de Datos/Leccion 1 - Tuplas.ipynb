# %%
tupla = (100, "hola", [1,2,3,4],-50)
tupla
# Out:
# (100, 'hola', [1, 2, 3, 4], -50)

# %%
tupla[-1]
# Out:
# -50

# %%
tupla[0:]
# Out:
# (100, 'hola', [1, 2, 3, 4], -50)

# %%
tupla[2][-4]
# Out:
# 1

# %%
len(tupla)
# Out:
# 4

# %%
len(tupla[2])
# Out:
# 4

# %%
#  Index para buscar un elemento y saber su posicion
tupla.index(100)
# Out:
# 0

# %%
tupla.index(-50)
# Out:
# 3

# %%
tupla.count(100) # Indica cuantas veces aparece el numero 100
# Out:
# 1

# %%
tupla = (100, 100, 10, 100)
tupla.count(100)
# Out:
# 3

# %%
lista = [1, 1, 2, 3, 4, 5, 6]
lista
lista.count(1)
# Out:
# 2
