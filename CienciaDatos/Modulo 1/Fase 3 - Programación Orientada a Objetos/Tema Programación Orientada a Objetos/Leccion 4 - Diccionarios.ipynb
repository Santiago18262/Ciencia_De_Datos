# %% [markdown]
# ## Diccionarios ##

# %%
colores = {"amarillo":"yellow", "azul":"blue", "negro":"black"}
colores['negro']
# Out:
# 'black'

# %%
colores.get('rojo', 'Color no encontrado')
# Out:
# 'Color no encontrado'

# %%
colores.get('negro')
# Out:
# 'black'

# %%
'negro' in colores
# Out:
# True

# %%
clave = input("Teclea un color ")
if clave in colores:
    print("El elemento si existe")
else:
    print("No existe")
# Out:
# No existe

# %%
colores.keys()
# Out:
# dict_keys(['amarillo', 'azul', 'negro'])

# %%
colores.values()
# Out:
# dict_values(['yellow', 'blue', 'black'])

# %%
colores.items()
# Out:
# dict_items([('amarillo', 'yellow'), ('azul', 'blue'), ('negro', 'black')])

# %%
for c in colores:
    print(c)
# Out:
# amarillo
# azul
# negro

# %%
for c in colores.keys():
    print(c)
# Out:
# amarillo
# azul
# negro

# %%
for c,k in colores.items():
    print(c,k)
# Out:
# amarillo yellow
# azul blue
# negro black

# %%
colores.items()
# Out:
# dict_items([('amarillo', 'yellow'), ('azul', 'blue'), ('negro', 'black')])

# %%
colores.pop('amarillo', 'No se encuentra')
# Out:
# 'yellow'

# %%
colores.pop('amarillo', 'No se encuentra')
# Out:
# 'No se encuentra'

# %%
colores.items()
# Out:
# dict_items([('azul', 'blue'), ('negro', 'black')])

# %%
colores.clear()

# %%
colores
# Out:
# {}
