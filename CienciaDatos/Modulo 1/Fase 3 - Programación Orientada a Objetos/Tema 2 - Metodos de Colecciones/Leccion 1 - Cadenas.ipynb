# %%
c = "Hola Mundo"

# %%
c.upper() # Hace que todo el texto este en mayusculas
# Out:
# 'HOLA MUNDO'

# %%
c.lower() # Hace que todo el texto este en minusculas
# Out:
# 'hola mundo'

# %%
c.capitalize() # Hace que se coloque en mayuscula la primera letra
# Out:
# 'Hola mundo'

# %%
c.title() # Hace que se coloque en mayuscula la primera letra de cada palabra
# Out:
# 'Hola Mundo'

# %%
c.count('o') # Cuentas cuantas 'o' tiene el texto
# Out:
# 2

# %%
B = 'Hola mundo como estas ahora en el mundo, dime Hola por favor mundo'
B.count('mundo')
# Out:
# 3

# %%
B.find('mundo')
# Out:
# 5

# %%
B.rfind('mundo')
# Out:
# 61

# %%
A = "100"

# %%
A.isdigit()
# Out:
# True

# %%
C2 = "ABC1000w#a"

# %%
C2.isalnum()
# Out:
# False

# %%
C2.isalpha()
# Out:
# False

# %%
"Hola mundo".islower()
# Out:
# False

# %%
"Hola mundo".isupper()
# Out:
# False

# %%
"Hola mundo".istitle()
# Out:
# False

# %%
"Hola Mundo".istitle()
# Out:
# True

# %%
"    A     ".isspace()
# Out:
# False

# %%
"       ".isspace()
# Out:
# True

# %%
"Hola mundo".startswith("H")
# Out:
# True

# %%
"Hola mundo".startswith("Hola")
# Out:
# True

# %%
"Hola mundo".endswith("o")
# Out:
# True

# %%
"Hola mundo".split() # Lo separa en base a los espacios
# Out:
# ['Hola', 'mundo']

# %%
"Hola mundo".split()[0]
# Out:
# 'Hola'

# %%
"Hola mundo".split()[1]
# Out:
# 'mundo'

# %%
"Hola mundo".split()[-1]
# Out:
# 'mundo'

# %%
"Hola mundo, Hola, mundo, Hola mundo".split(',')
# Out:
# ['Hola mundo', ' Hola', ' mundo', ' Hola mundo']

# %%
",".join("Hola Mundo")
# Out:
# 'H,o,l,a, ,M,u,n,d,o'

# %%
",".join("Hola Mundo")
# Out:
# 'H,o,l,a, ,M,u,n,d,o'

# %%
" ".join("Hola")
# Out:
# 'H o l a'

# %%
"--------- Hola Mundo ---------".strip("-")
# Out:
# ' Hola Mundo '

# %%
"          Hola Mundo          ".strip(" ")
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo".replace('o','0')
# Out:
# 'H0la Mund0'

# %%
"Hola Mundo".replace('Mundo','Marte')
# Out:
# 'Hola Marte'
