# %%
numeros = [1, 2, 3, 4]

# %%
numeros
# Out:
# [1, 2, 3, 4]

# %%
dato = [4, "Una cadena", -15, 3.14, True, "Otra cadena"]

# %%
dato
# Out:
# [4, 'Una cadena', -15, 3.14, True, 'Otra cadena']

# %%
dato.
# Out:
#   Cell In[6], line 1
#     dato.
#          ^
# SyntaxError: invalid syntax

# %%
dato[-3]
# Out:
# 3.14

# %%
dato[-1]
# Out:
# 'Otra cadena'

# %%
dato[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dato[:]
#
# NameError: name 'dato' is not defined

# %%
dato[-2:]
# Out:
# [True, 'Otra cadena']

# %%
numeros = [3, 2]

# %%
numeros+[5, 6, 7, 8]
# Out:
# [3, 2, 5, 6, 7, 8]

# %%
numeros
# Out:
# [3, 2]

# %%
valor = numeros+[5, 6, 7, 8]
valor
# Out:
# [3, 2, 5, 6, 7, 8]

# %%
pares = [0, 2, 4, 6, 8, 10]
pares
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
pares[3] = 6

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
pares[5] = 12

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 12]

# %%
# Agregando un nuevo elemento
pares.append(14)

# %%
pares.append(11)

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 12, 14, 11]

# %%
pares.append(7*3)

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 12, 14, 11, 21]

# %%
pares.sort()  # Ordena los elementois de la lista de menor a mayor
pares
# Out:
# [0, 2, 4, 6, 8, 11, 12, 14, 21]

# %%
pares.reverse() # Ordena los elementos de la lista de mayor a menor
pares
# Out:
# [21, 14, 12, 11, 8, 6, 4, 2, 0]

# %%
pares.pop() # Elimina el ultimo elemento de la lista
# Out:
# 0

# %%
pares
# Out:
# [21, 14, 12, 11, 8, 6, 4, 2]

# %%
valor = pares.pop()
valor
# Out:
# 2

# %%
pares
# Out:
# [21, 14, 12, 11, 8, 6, 4]

# %%
pares.sort()
pares
# Out:
# [4, 6, 8, 11, 12, 14, 21]

# %%
# Eliminamos un elemento en especifico
pares.remove(14)
pares
# Out:
# [4, 6, 8, 11, 12, 21]

# %%
ejemplo = [1,2,2,3,4]
ejemplo
# Out:
# [1, 2, 2, 3, 4]

# %%
ejemplo.remove(2)

# %%
ejemplo
# Out:
# [1, 2, 3, 4]

# %%
pares
# Out:
# [4, 6, 8, 11, 12, 21]

# %%
pares.append(10)
pares.append(10)
pares.append(10)
total_de_10 = pares.count(10)

# %%
total_de_10
# Out:
# 3

# %%
pares.count(11)
# Out:
# 1

# %%
letras = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
letras[:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
letras[:3] = ['A', 'B', 'C', 'd', 'e', 'f']
letras
# Out:
# ['A', 'B', 'C', 'd', 'e', 'f', 'd', 'e', 'f']

# %%
len(letras) # Sirve para contar el total de elementos de una lista
# Out:
# 9

# %%
a = [ 1, 2,3]
b = [4, 5, 6]
c = [7, 8, 9]
j = ["x", "y", "z"]

d = [a, b, c, j]
d
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9], ['x', 'y', 'z']]

# %%
d[0]
# Out:
# [1, 2, 3]

# %%
d[-1]
# Out:
# ['x', 'y', 'z']

# %%
d[2]
# Out:
# [7, 8, 9]
