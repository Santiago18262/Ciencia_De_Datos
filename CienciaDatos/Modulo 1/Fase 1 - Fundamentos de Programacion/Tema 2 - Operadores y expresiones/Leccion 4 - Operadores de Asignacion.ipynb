# %%
a = 1

# %%
# Asignacion por incremento
a + 3 # Operador suma de asignacion a = a +1
a

# %%
a -= 10
a

# %%
a = 5
a *= 4 # Multiplicacion en asignacion
a

# %%
a = 3
a /= 2 # Division en asignacion
a

# %%
a = 4
a %= 2 # Modulo en asignacion
a

# %%
a = 4
a **= 10 # Producto en asignacion
a
