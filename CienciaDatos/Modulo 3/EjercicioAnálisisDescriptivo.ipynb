# %%
import pandas as pd

# %%
data = pd.read_csv('../Modulo 2/Pandas/fortune1000.csv')
data.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
# Análisis descriptivo
data[["Revenue", "Profits", "Employees"]].describe()
# Out:
#              Revenue       Profits     Employees
# count    1000.000000   1000.000000  1.000000e+03
# mean    13535.525000    894.093000  3.302800e+04
# std     28820.519135   3297.063594  9.042769e+04
# min      1895.000000 -23119.000000  5.200000e+01
# 25%      2898.250000     82.750000  6.405250e+03
# 50%      5113.000000    282.500000  1.251950e+04
# 75%     11386.000000    784.500000  2.812500e+04
# max    482130.000000  53394.000000  2.300000e+06

# %%
data.shape
# Out:
# (1000, 8)

# %%
"""
Calcular la media, moda, mediana de cada una de las columnas númericas y explicar porque se muestra ese resultado para después
realizar un histograma
"""

print("Análisis descriptivo para cada columna numérica:")
for column in ["Revenue", "Profits", "Employees"]:
    media = data[column].mean()
    mediana = data[column].median()
    moda = data[column].mode()[0]
    print(f"{column} - Media: {media}, Mediana: {mediana}, Moda: {moda}")

print("\nDesviación estándar y varianza para cada columna numérica:")
for column in ["Revenue", "Profits", "Employees"]:
    desviacionestandar = data[column].std()
    varianza = data[column].var()
    print(f"{column} - Desviación estándar: {desviacionestandar}, Varianza: {varianza}")
# Out:
# Análisis descriptivo para cada columna numérica:
# Revenue - Media: 13535.525, Mediana: 5113.0, Moda: 2084
# Profits - Media: 894.093, Mediana: 282.5, Moda: 172
# Employees - Media: 33028.002, Mediana: 12519.5, Moda: 13000
#
# Desviación estándar y varianza para cada columna numérica:
# Revenue - Desviación estándar: 28820.519134890328, Varianza: 830622323.2045796
# Profits - Desviación estándar: 3297.0635939717167, Varianza: 10870628.342693694
# Employees - Desviación estándar: 90427.69075123282, Varianza: 8177167254.600597

# %%
# Histograma para cada columna numérica
import matplotlib.pyplot as plt

for column in ["Revenue", "Profits", "Employees"]:
    plt.figure(figsize=(10, 6))
    plt.hist(data[column], bins=30, edgecolor='black')
    plt.title(f'Histograma de {column}')
    plt.xlabel(column)
    plt.ylabel('Frecuencia')
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %%
# Explicacion de cada uno de los histogramas

"""
Columna Revenue: Se observa que la mayoría de las empresas tienen ingresos relativamente bajos, mientras que hay algunas empresas 
                 con ingresos extremadamente altos, lo que sugiere una distribución sesgada hacia la derecha.
Columna Profit: Similar a la columna de ingresos, la mayoría de las empresas tienen ganancias relativamente bajas, mientras que 
                hay algunas empresas con ganancias extremadamente altas, lo que también sugiere una distribución sesgada hacia 
                la derecha.
Columna Employees: Se muestra que la mayoría de las empresas tienen un número relativamente bajo de empleados, mientras que hay 
                 algunas empresas con un número extremadamente alto de empleados, lo que sugiere una distribución sesgada hacia 
                 la derecha.
"""
# Out:
# '\nColumna Revenue: Se observa que la mayoría de las empresas tienen ingresos relativamente bajos, mientras que hay algunas empresas \n                 con ingresos extremadamente altos, lo que sugiere una distribución sesgada hacia la derecha.\nColumna Profit: Similar a la columna de ingresos, la mayoría de las empresas tienen ganancias relativamente bajas, mientras que \n                hay algunas empresas con ganancias extremadamente altas, lo que también sugiere una distribución sesgada hacia \n                la derecha.\nColumna Employees: Se muestra que la mayoría de las empresas tienen un número relativamente bajo de empleados, mientras que hay \n                 algunas empresas con un número extremadamente alto de empleados, lo que sugiere una distribución sesgada hacia \n                 la derecha.\n'

# %%
# Boxplot para cada columna númerica

for column in ["Revenue", "Profits", "Employees"]:
    plt.figure(figsize=(10, 6))
    plt.boxplot(data[column])
    plt.title(f'Boxplot de {column}')
    plt.ylabel(column)
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %%
# Explicacion de cada uno de los boxplots

"""
Columna Revenue: El boxplot muestra que la mayoría de las empresas tienen ingresos relativamente bajos, con algunos valores atípicos
                 que representan empresas con ingresos altos.
Columna Profit: Similar al boxplot de ingresos, la mayoría de las empresas tienen ganancias relativamente bajas, con algunos valores
                atípicos que representan empresas con ganancias altas.
Columna Employees: El boxplot muestra que la mayoría de las empresas tienen un número relativamente bajo de empleados, con algunos 
                   valores atípicos que representan empresas con un número alto de empleados.
"""

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Modulo 2/Pandas/nba.csv")

df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.shape
# Out:
# (458, 9)

# %%
df.describe()
# Out:
#            Number         Age      Weight
# count  457.000000  457.000000  457.000000
# mean    17.678337   26.938731  221.522976
# std     15.966090    4.404016   26.368343
# min      0.000000   19.000000  161.000000
# 25%      5.000000   24.000000  200.000000
# 50%     13.000000   26.000000  220.000000
# 75%     25.000000   30.000000  240.000000
# max     99.000000   40.000000  307.000000

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary       object
# dtype: object

# %%
for column in ["Number", "Age", "Weight"]:
    plt.figure(figsize=(10, 6))
    plt.boxplot(df[column])
    plt.title(f'Boxplot de {column}')
    plt.ylabel(column)
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %%
# Convertir a numero 
df["Height"] = pd.to_numeric(df["Height"], errors='coerce')
df["Salary"] = pd.to_numeric(df["Salary"], errors='coerce')

# %%
columnas = ["Age", "Number", "Weight", "Salary"]

dfx = df[columnas].corr()

sns.heatmap(dfx, annot= True, cmap = 'viridis')
plt.show()
