# %%
conjunto = set()

# %%
conjunto = [1,2,3]
conjunto
# Out:
# [1, 2, 3]

# %%
grupo = {'hector', 'juan', 'mario'}
'hector' in grupo
# Out:
# True

# %%
nombre = input("Ingresa el nombre a buscar: ")
if nombre in grupo:
    print("La persona si existe")
else: 
    print("La persona no existe")
# Out:
# La persona si existe

# %%
nombre = input("Ingresa el nombre a buscar: ")
if not nombre in grupo:
    print("La persona no existe")
else: 
    print("La persona si existe")
# Out:
# La persona no existe

# %%
'hector' not in grupo
# Out:
# False

# %%
test = {'hector', 'hector'} # No permiten elementos repetidos en el test
test
# Out:
# {'hector'}

# %%
lista = [1,2,3,4,5,5,5,5]
c = set(lista)
c
# Out:
# {1, 2, 3, 4, 5}

# %%
l = [1,2,3,4,5,4,3,2]
l = list(set(l))
l
# Out:
# [1, 2, 3, 4, 5]

# %%
grupo = {"Miguel", "Blanca", "Mario", "Andres"}

# Complete el ejercicio

grupo.add("Ana")
grupo.add("Ramon")
grupo.add("Marta")
grupo.add("Eric")
grupo.add("David")

grupo.remove("Mario")
grupo.remove("Miguel")
grupo.remove("Ramon")
grupo
# Out:
# {'Ana', 'Andres', 'Blanca', 'David', 'Eric', 'Marta'}

# %%
elementos = {1,2,3}
elementos
# Out:
# {1, 2, 3}

# %%
elementos.add(-3)
elementos
# Out:
# {-3, 1, 2, 3}

# %%
elementos.add(0)
elementos
# Out:
# {-3, 0, 1, 2, 3}

# %%
elementos.add(4)
elementos
# Out:
# {-3, 0, 1, 2, 3, 4}

# %%
elementos.add("g")
elementos
# Out:
# {-3, 0, 1, 2, 3, 4, 'g'}

# %%
elementos.add("a")
elementos
# Out:
# {-3, 0, 1, 2, 3, 4, 'a', 'g'}

# %%
elementos.add("A")
elementos
# Out:
# {-3, 0, 1, 2, 3, 4, 'A', 'a', 'g'}

# %%
conjuntoA = set()
conjuntoA={-3, 0, 1}
conjuntoA.issubset(elementos) # Preguntamos si es un subconjunto
conjuntoA.intersection(elementos) # Preguntamos por la interseccion entre 2 conjuntos
# Out:
# {-3, 0, 1}

# %%
union = set()
union = conjuntoA.union(elementos)
union
conjuntoA.isdisjoint(elementos)
conjuntoA
elementos
# Out:
# {-3, 0, 1, 2, 3, 4, 'A', 'a', 'g'}
